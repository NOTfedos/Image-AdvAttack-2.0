# %%
from PIL import Image
from torchvision import transforms, datasets

import numpy as np
from matplotlib import pyplot as plt
import math

from tqdm import tqdm
from datetime import datetime

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision.transforms import v2

from torch.utils.tensorboard import SummaryWriter

'''
    WARNING: check experiment number!!!
'''

import masks

# %%
trainset = datasets.CIFAR10(root='./data/cifar10', train=True, download=True, transform=transforms.ToTensor())
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %%
index = 40
test_image = torch.ones((3, 64, 64))# trainset[index][0]
label = 5 # trainset[index][1]
print(f"{label=}")
f, axs = plt.subplots(1,2, figsize=(12, 8))
axs[0].imshow(test_image.permute(1, 2, 0))
axs[0].set_title(f"Исходное изображение",fontsize=20)
axs[0].set_xticks([])
axs[0].set_yticks([])
# axs[1].imshow(mask_part(test_image.unsqueeze(0), label, 10).squeeze().permute(1, 2, 0))
axs[1].imshow(masks.MaskImageAll(5, 10)(test_image).permute(1, 2, 0).detach().numpy())
axs[1].set_title(f"Маска для класса 5", fontsize=20)
axs[1].set_xticks([])
axs[1].set_yticks([])
# Out:
# label=5
# []

# %%
plt.imshow(masks.MaskImageAll(5, 10)(test_image).permute(1, 2, 0).detach().numpy())
plt.savefig("./mask_on_white.png")

# %%
import torchvision
read_image = torch.randn((3, 64, 64))
plt.imshow((read_image.permute(1, 2, 0).cpu().detach().numpy() * 255).astype(np.uint8))
plt.savefig("./read_image.png")

# %%
masked = masks.MaskImageAll(5, 10)(read_image)

# %%
plt.imshow((masked.permute(1, 2, 0).cpu().detach().numpy() * 255).astype(np.uint8))
plt.savefig("./masked_read_image.png")
# plt.savefig("./mask_on_white.png")
